# %% [markdown]
# <a href="https://colab.research.google.com/github/Minu1p/Minu1p/blob/master/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2      #cv2 is noting but open cv used for image proessing
import numpy as np

#read an image
img=cv2.imread('apple.jpg')
print(img.shape)

(225,225,3)
# Out:
# (128, 124, 3)
# (225, 225, 3)

# %%
#this is the package you need to import to make below command run
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()

#converting RGB image to grayscale image
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(img_gray.shape)
cv2_imshow(img_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

(225,225)

#resizing image
img_resize=cv2.resize(img,(500,500))
cv2_imshow(img_resize)
cv2.waitKey(0)

#flipping an image
img_flip=cv2.flip(img,1)     #-1 to flip it try 0 nd 1 and see
cv2_imshow(img_flip)
cv2.waitKey(0)
cv2.destroyAllWindows()

#crop the image
img_crop=img[0:300,0:300]    #height wuth starting index and  width with starting and ending index
cv2_imshow(img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()


#convert grayscale img to binary img
ret,binary=cv2.threshold(img_gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

#NOW detect the contour
contours, hierarchy=c2.findContours(binary, mode=cv2.RETR_TREE, method=cv2.CHA)

#visualize the data structures
print("length of contours".format(len(contours)))

print(contours)
# Out:
# <PIL.Image.Image image mode=RGB size=124x128 at 0x7FE7EEC07D60>
# (128, 124)
# <PIL.Image.Image image mode=L size=124x128 at 0x7FE7EEC07280>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FE7EEC07A30>
# <PIL.Image.Image image mode=RGB size=124x128 at 0x7FE7EEC07EB0>
# <PIL.Image.Image image mode=RGB size=124x128 at 0x7FE7EEC076A0>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ff09217228d5> in <module>
#      36
#      37 #NOW detect the contour
# ---> 38 contours, hierarchy=c2.findContours(binary, mode=cv2.RETR_TREE, method=cv2.CHA)
#      39
#      40 #visualize the data structures
#
# NameError: name 'c2' is not defined
